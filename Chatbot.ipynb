# %% [markdown]
# <a href="https://colab.research.google.com/github/Camarenita/Chatbot/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi

# %%
cd /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot
# Out:
# /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot

# %%
# !git clone --recursive https://github.com/daniel-kukiela/nmt-chatbot
# Out:
# Cloning into 'nmt-chatbot'...
# remote: Enumerating objects: 823, done.
# remote: Total 823 (delta 0), reused 0 (delta 0), pack-reused 823
# Receiving objects: 100% (823/823), 11.75 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (466/466), done.
# Submodule 'nmt' (https://github.com/daniel-kukiela/nmt) registered for path 'nmt'
# Cloning into '/content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot/nmt-chatbot/nmt'...
# remote: Enumerating objects: 1373, done.
# remote: Total 1373 (delta 0), reused 0 (delta 0), pack-reused 1373
# Receiving objects: 100% (1373/1373), 1.27 MiB | 6.82 MiB/s, done.
# Resolving deltas: 100% (985/985), done.
# Submodule path 'nmt': checked out '33acea2284a2d719773d73fdd8e751e4ce734dfe'

# %%
cd nmt-chatbot
# Out:
# /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot/nmt-chatbot

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
cd setup
# Out:
# /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot/nmt-chatbot/setup

# %%
# !python prepare_data.py
# Out:
# Preparing training set from raw set
# File: train.from
# 100% 3280722/3280722 [05:20<00:00, 10232.59 lines/s]
# File: tst2012.from
# 100% 100/100 [00:00<00:00, 751.22 lines/s]
# File: tst2013.from
# 100% 100/100 [00:00<00:00, 1492.58 lines/s]
# File: train.to
# 100% 3280722/3280722 [05:00<00:00, 10908.32 lines/s]
# File: tst2012.to
# 100% 100/100 [00:00<00:00, 674.03 lines/s]
# File: tst2013.to
# 100% 100/100 [00:00<00:00, 1623.33 lines/s]
#
# Learning BPE
# Building temporary vocab (from)
# 1244845 tokens [00:18, 66922.09 tokens/s]
# Learning BPE for vocab of 15000 tokens
# 100% 15000/15000 [01:20<00:00, 185.30 tokens/s]
#
# Applying BPE
# File: train.bpe.from
# 100% 3280722/3280722 [03:17<00:00, 16600.12 lines/s]
# File: tst2012.bpe.from
# 100% 100/100 [00:00<00:00, 1087.64 lines/s]
# File: tst2013.bpe.from
# 100% 100/100 [00:00<00:00, 1040.20 lines/s]
# File: train.bpe.to
# 100% 3280722/3280722 [03:03<00:00, 17853.47 lines/s]
# File: tst2012.bpe.to
# ...

# %%
cd ../
# Out:
# /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot

# %%
# !python train.py
# Out:
# Training model...
#
# Epoch: 1, learning rate: 0.001 - already passed
#
# Epoch: 2, steps per epoch: 25631, epoch ends at 51262 steps, learning rate: 0.0001 - training
#
# WARNING:tensorflow:From train.py:88: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0619 06:02:16.432079 140563945170688 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# ...

# %%
# !python inference.py
# Out:
# Starting interactive mode (first response will take a while):
#
# > Hi
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From inference.py:57: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Escuela/6to/Inteligencia Artificial/3er Parcial/Chatbot/nmt-chatbot/nmt/nmt/utils/misc_utils.py:97: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
